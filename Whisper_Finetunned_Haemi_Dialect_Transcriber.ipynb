# %% [markdown]
# <a href="https://colab.research.google.com/github/HiTECHFullOn/HiTECHFullOn/blob/main/Whisper_Finetunned_Haemi_Dialect_Transcriber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets>=2.6.1
# !pip install git+https://github.com/huggingface/transformers
# !pip install evaluate>=0.30
# !pip install jiwer
# !pip install accelerate -U
# !pip install transformers[torch]
# !pip install wandb
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-ia89d7ag
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-ia89d7ag
#   Resolved https://github.com/huggingface/transformers to commit 33868a057c02f0368ba63bd1edb746be38fe3d90
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 40.0 MB/s eta 0:00:00
# ...
#   Created wheel for transformers: filename=transformers-4.47.0.dev0-py3-none-any.whl size=10057149 sha256=38dc289b6db660c43082cddd22d030e3c86e5ea68c7355857d88461562c0dba5
# ...

# %%
from transformers import pipeline
pipe = pipeline(model="Cosmosplendor/gear-and-ear")
# Out:
# config.json:   0%|          | 0.00/1.31k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/290M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.12k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/296k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.09M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/544k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/54.4k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/36.2k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.33k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/353 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
def transcribe(audio):
    text = pipe(audio)["text"]
    return text

# %%
transcribe("audio.wav")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:496: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# ' 진짜 거기서 살 때는 주머니라고 했으면 우리 시알만지가 시집 보니까 근랑이라고 그러더라고 근랑이 뭐가 뭐가 주머니 소리가 근랑이라고 그러더라고 우리 시알만지가 그렇게 살았어요 그렁께 모든 게 우리 천안 지역에 살 때는 먹는 것도 나는 동태하고 오징어하고 고등어팩이 몰랐어요 아버지가 그것만 사 오시자면 여기 오니까 막 살 쪽에라는 거 일구 댕임에 저녁에 팔고'
